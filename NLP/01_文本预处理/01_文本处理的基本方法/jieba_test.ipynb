# %%
import  jieba
content="传智hello教育是一家上市公司，旗下有黑马程序员品牌。我是在黑马这里学习人工智能"
words=jieba.lcut(content)
print(words)
# Out:
# C:\Users\Administrator\.conda\envs\nlp_base\lib\site-packages\jieba\_compat.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 1.332 seconds.
# Prefix dict has been built successfully.
# ['传智', 'hello', '教育', '是', '一家', '上市公司', '，', '旗下', '有', '黑马', '程序员', '品牌', '。', '我', '是', '在', '黑马', '这里', '学习', '人工智能']

# %%
word =jieba.lcut(content,cut_all=True)
print(word)
# Out:
# ['传', '智', 'hello', '教育', '是', '一家', '上市', '上市公司', '公司', '，', '旗下', '下有', '黑马', '程序', '程序员', '品牌', '。', '我', '是', '在', '黑马', '这里', '学习', '人工', '人工智能', '智能']

# %%
 word123 = jieba.lcut_for_search(content)
 print( word123)
# Out:
# ['传智', 'hello', '教育', '是', '一家', '上市', '公司', '上市公司', '，', '旗下', '有', '黑马', '程序', '程序员', '品牌', '。', '我', '是', '在', '黑马', '这里', '学习', '人工', '智能', '人工智能']

# %%
# 词典路径：与 demo 一致用 data 目录；或用同目录下的 mydict（注意文件名无 .txt）
jieba.load_userdict("../data/my_dict.txt")
result = jieba.lcut(content)
result
# Out:
# ['传智hello教育',
#  '是',
#  '一家',
#  '上市公司',
#  '，',
#  '旗下',
#  '有',
#  '黑马程序员',
#  '品牌',
#  '。',
#  '我是',
#  '在',
#  '黑马',
#  '这里',
#  '学习',
#  '人工智能']

# %%
import jieba.posseg as pseg

res=pseg.lcut(content)
print(res)
for a,b in res:
    print(a,b)
# Out:
# [pair('传智hello教育', 'n'), pair('是', 'v'), pair('一家', 'm'), pair('上市公司', 'nt'), pair('，', 'x'), pair('旗下', 'n'), pair('有', 'v'), pair('黑马程序员', 'x'), pair('品牌', 'n'), pair('。', 'x'), pair('我是', 'x'), pair('在', 'p'), pair('黑马', 'ns'), pair('这里', 'r'), pair('学习', 'v'), pair('人工智能', 'n')]
# 传智hello教育 n
# 是 v
# 一家 m
# 上市公司 nt
# ， x
# 旗下 n
# 有 v
# 黑马程序员 x
# 品牌 n
# 。 x
# 我是 x
# 在 p
# 黑马 ns
# 这里 r
# 学习 v
# 人工智能 n
